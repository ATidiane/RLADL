# %% [markdown]
# # Deep Q Network

# %%
import sys
import argparse
import copy
import json
import random
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set; sns.set_style("whitegrid")
import gym
from gym import wrappers, logger

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torch.nn.functional as F

from collections import deque
import random
from utils import set_all_seeds
from tqdm import tqdm
# Out:
# <function seaborn.rcmod.set>

# %%
class NN(nn.Module):
    def __init__(self, inSize, outSize, layers=[]):
        super(NN, self).__init__()
        self.layers = nn.ModuleList([])
        for x in layers:
            self.layers.append(nn.Linear(inSize, x))
            inSize = x
        self.layers.append(nn.Linear(inSize, outSize))
        
    def forward(self, x):
        x = self.layers[0](x)
        for i in range(1, len(self.layers)):
            x = torch.nn.functional.leaky_relu(x)
            x = self.layers[i](x)
        return x

# %%
class DQL_ER(object):
    def __init__(self, inSize, outSize, env, envx, layers=[200], size_deque=300,
                 minibatch_size=200, eps=0.5, gamma=0.99, lr=0.001, C=4):
        self.D = deque(maxlen=size_deque)
        self.action_space = env.action_space
        self.Q = NN(inSize, outSize, layers)
        self.Q_hat = NN(inSize, outSize, layers)
        self.Q_hat.load_state_dict(self.Q.state_dict())
        self.optimizer = optim.Adam(self.Q.parameters(), lr=lr)
        self.loss = nn.MSELoss()  # nn.SmoothL1Loss()

        self.eps = eps
        self.C = C
        self.envx = envx
        self.gamma = gamma
        self.minibatch_size = minibatch_size

    def fit(self, M, graph=True, verbose=False):
        reward_list = []
        loss_list = []
        v = 0
        c = 1
        for m in range(M):
            state = env.reset()
            done = False
            r = 0
            mean_reward = []
            mean_loss = []
            while not done:
                # With probability eps select a random action
                action = self.select_action(state)

                # Execute action and observe reward r and next state
                next_state, reward, done, _ = env.step(action)
                r += reward

                # Si done = True alors 1 - done = 0 et on retrouve bien que
                # target = reward
                target = reward + (1 - done) * self.gamma * \
                    self.get_max(next_state)
                self.D.append([state, action, reward, next_state, target])

                # Gradient descent
                if c >= self.minibatch_size:
                    minibatch = random.sample(self.D, self.minibatch_size)
                    y = torch.tensor([mb[4] for mb in minibatch],
                                     dtype=torch.float32)
                    x = torch.tensor([mb[0] for mb in minibatch],
                                     dtype=torch.float32, requires_grad=True)
                    self.optimizer.zero_grad()
                    y_pred = self.Q(x)
                    loss = self.loss(torch.max(y_pred, 1)[0], y)
                    loss.backward()
                    self.optimizer.step()   
                    mean_reward.append(r)
                    mean_loss.append(loss)
                        
                    if done:
                        reward_list.append(sum(mean_reward)/len(mean_reward))
                        loss_list.append(sum(mean_loss)/len(mean_loss))
                    
                    if c % self.C == 0:
                        self.Q_hat.load_state_dict(self.Q.state_dict())
                                        
                state = next_state
                c += 1
                                                         
            if verbose:
                print("itération:", v, "reward:", r)

            v += 1
            self.update_eps()

            if c % 100 == 0:
                self.test(self.envx, 1, verbose=True, graph=False)
        results = pd.DataFrame(np.vstack((reward_list, list(map(lambda t: t.item(), loss_list)))).T, columns=['reward', 'loss'])
        results.to_csv("dqn_lunarlander.csv", index=False)
        
        if graph:
            x = [i for i in range(1, M + 1)]
            sns.set_style("whitegrid")
            plt.figure(figsize=(10, 6))
            plt.plot(range(len(reward_list)), reward_list, color='darkblue')
            plt.xlabel("Nombre de parties")
            plt.ylabel("Score")
            plt.title("Reward")
            plt.show()
            plt.figure(figsize=(10, 6))
            plt.plot(range(len(loss_list)), loss_list, color='darkred')
            plt.xlabel("Nombre de parties")
            plt.ylabel("Loss")
            plt.show()

    def select_action(self, state):
        if np.random.uniform() < self.eps:
            return self.action_space.sample()

        with torch.no_grad():
            pred = self.Q(torch.tensor(state, dtype=torch.float32))
        return torch.argmax(pred).numpy()

    def act(self, state):
        with torch.no_grad():
            pred = self.Q(torch.tensor(state, dtype=torch.float32))
        return torch.argmax(pred).numpy()

    def get_max(self, next_state):
        with torch.no_grad():
            #pred = self.Q(torch.tensor(next_state, dtype=torch.float32))
            pred = self.Q_hat(torch.tensor(next_state, dtype=torch.float32))
        maxi = torch.max(pred.detach())
        return maxi

    def update_eps(self):
        self.eps -= 0.005

    def test(self, envx, T, graph=True, verbose=False, demo_jeu=False):
        reward_list = []
        for i in range(T):
            if demo_jeu:
                envx.render(1)
            state = env.reset()
            done = False
            r = 0
            while not done:
                action = self.act(state)
                if demo_jeu:
                    envx.render()
                next_state, reward, done, _ = env.step(action)
                r += reward
                state = next_state

            if verbose:
                print(r)
            reward_list.append(r)
        if graph:
            plt.plot([i for i in range(1, T + 1)], reward_list)
            plt.xlabel("Nombre de parties")
            plt.ylabel("Score")
            plt.show()

# %% [markdown]
# ## CartPole

# %%
inSize = 4
outSize = 2
M = 700

env_id = 'CartPole-v1'
outdir = 'cartpole-v0/random-agent-results'
envx = gym.make(env_id)
envx.verbose = True
env = envx
env = wrappers.Monitor(envx, directory=outdir, force=True,
                       video_callable=False)
set_all_seeds(env, seed=1)

dql = DQL_ER(inSize, outSize, env, envx)
dql.fit(M, graph=False, verbose=True)

# %% [markdown]
# ## LunarLander

# %%
eps = 0.1
lr = 0.001
M = 1000
minibatch_size = 32
size_deque = 1000000
layers = [20, 20]
gamma = 0.9


env_id = 'LunarLander-v2'
outdir = 'LunarLander-v2/random-agent-results'
envx = gym.make(env_id)
envx.verbose = True
env = envx
env = wrappers.Monitor(envx, directory=outdir, force=True,
                       video_callable=False)
set_all_seeds(env, seed=0)

inSize = env.observation_space.shape[0]
outSize = env.action_space.n


dql = DQL_ER(inSize, outSize, env, envx, eps=eps, lr=lr, size_deque=size_deque, layers=layers,
             minibatch_size=minibatch_size, gamma=gamma)
dql.fit(M, verbose=True, graph=False)
# Out:
# itération: 0 reward: -166.51774379966204
# itération: 1 reward: -178.00211686165625
# itération: 2 reward: -165.84237934706584
# itération: 3 reward: -105.15512657656268
# itération: 4 reward: -104.14215029712724
# itération: 5 reward: -124.51097775319576
# itération: 6 reward: -12.496357330648536
# itération: 7 reward: -113.74187502073629
# itération: 8 reward: -118.69478970383526
# itération: 9 reward: -145.47021113342925
# itération: 10 reward: -141.82036552336103
# itération: 11 reward: -145.63526210010173
# itération: 12 reward: -101.10689307044467
# itération: 13 reward: -187.36825899654832
# itération: 14 reward: -264.0566585160358
# itération: 15 reward: -378.59188442090715
# itération: 16 reward: -297.5208808993656
# itération: 17 reward: -104.36071701455361
# itération: 18 reward: -160.44392873290047
# -137.133239821772
# itération: 19 reward: 8.020490484952205
# itération: 20 reward: -173.54690042360534
# itération: 21 reward: -136.1416559511919
# itération: 22 reward: -116.52501216255246
# itération: 23 reward: -140.03114911167603
# itération: 24 reward: -289.3100756472198
# itération: 25 reward: -142.81494454368612
# itération: 26 reward: -99.6315769142841
# itération: 27 reward: -132.40167007711773
# itération: 28 reward: -224.0053600606675
# itération: 29 reward: -117.75468653666653
# itération: 30 reward: -92.05540667827981
# itération: 31 reward: -101.3164630708863
# itération: 32 reward: -140.9180322586076
# itération: 33 reward: -98.87734004213343
# itération: 34 reward: -132.46634816288656
# itération: 35 reward: 10.441971444480671
# itération: 36 reward: -125.72178975297308
# itération: 37 reward: -150.48290622227918
# itération: 38 reward: -99.46020996707176
# itération: 39 reward: -177.8552251248272
# itération: 40 reward: -127.3140482234408
# itération: 41 reward: -139.90536884326983
# itération: 42 reward: -159.302381652472
# itération: 43 reward: -195.99312370687846
# itération: 44 reward: -123.95612504784745
# itération: 45 reward: -99.88680159560835
# itération: 46 reward: -355.39641392816986
# itération: 47 reward: -107.75322821261247
# itération: 48 reward: -149.49211615911577
# itération: 49 reward: -177.97165456448752
# itération: 50 reward: -134.60293490785466
# itération: 51 reward: -130.62734392425625
# itération: 52 reward: -121.68289800829865
# itération: 53 reward: -38.043949913788225
# itération: 54 reward: -112.59019646761388
# itération: 55 reward: -109.72631111046336
# itération: 56 reward: -186.39861995899918
# itération: 57 reward: 32.486003288309746
# itération: 58 reward: -143.06665703521315
# itération: 59 reward: -176.89574353798784
# itération: 60 reward: -135.85661679289046
# itération: 61 reward: -163.40543049638887
# itération: 62 reward: -124.60956751963545
# itération: 63 reward: -148.47049533211663
# itération: 64 reward: -112.06520717532456
# itération: 65 reward: -145.03282845777736
# itération: 66 reward: -100.15035722094991
# itération: 67 reward: -154.4254304392942
# itération: 68 reward: -119.1327011997059
# itération: 69 reward: -113.14121271840169
# itération: 70 reward: -124.86489478946412
# itération: 71 reward: -142.8731657837049
# itération: 72 reward: -116.05966948940893
# itération: 73 reward: -49.59045625489644
# itération: 74 reward: -210.5752095794712
# itération: 75 reward: -92.73375500106317
# itération: 76 reward: -109.90298337897869
# itération: 77 reward: -141.69184482687191
# itération: 78 reward: -133.05094089688282
# itération: 79 reward: -124.64895768691233
# itération: 80 reward: -121.1822663768273
# itération: 81 reward: -135.66387268662115
# itération: 82 reward: -144.0290807439241
# itération: 83 reward: -163.86936861034266
# itération: 84 reward: -47.645182021131575
# itération: 85 reward: -134.34207267199662
# itération: 86 reward: -136.59676105135728
# itération: 87 reward: -109.69864324457458
# itération: 88 reward: -205.9967133559629
# itération: 89 reward: -134.5061476891877
# itération: 90 reward: -147.04433477245763
# itération: 91 reward: -120.38242524861042
# itération: 92 reward: -159.010077814335
# itération: 93 reward: -151.3327340493538
# itération: 94 reward: -124.13167652086602
# itération: 95 reward: -132.06856258905597
# itération: 96 reward: -121.00646740930603
# itération: 97 reward: -111.52376271258332
# itération: 98 reward: -152.55147575293728
# itération: 99 reward: -125.85863631147305
# itération: 100 reward: -127.59778541105123
# itération: 101 reward: -112.64101006958808
# itération: 102 reward: -135.46536523692413
# itération: 103 reward: -156.24063172542913
# itération: 104 reward: -155.19902629492785
# itération: 105 reward: -70.71282648000857
# itération: 106 reward: -130.49154919488714
# itération: 107 reward: -117.31233154382934
# itération: 108 reward: -130.50899084874726
# itération: 109 reward: -117.47631299219739
# itération: 110 reward: -127.47088940614279
# itération: 111 reward: -131.7879221095306
# itération: 112 reward: -123.50573511497836
# itération: 113 reward: -159.93357076321988
# itération: 114 reward: -87.35673630712301
# itération: 115 reward: 1.1358890915075364
# itération: 116 reward: -127.34759506815945
# itération: 117 reward: -137.01223832418341
# itération: 118 reward: -140.8713957873139
# itération: 119 reward: -91.12238955279082
# itération: 120 reward: -136.42751888185177
# itération: 121 reward: -119.00691819580173
# itération: 122 reward: -90.76000762805376
# itération: 123 reward: -182.99951808014126
# itération: 124 reward: -107.14184548726212
# itération: 125 reward: -96.15766859192422
# itération: 126 reward: -142.60555505025766
# itération: 127 reward: -118.33421722357548
# itération: 128 reward: -124.94078383935482
# itération: 129 reward: -126.59342173290936
# itération: 130 reward: -149.9905306372956
# itération: 131 reward: -122.52868666368988
# itération: 132 reward: -140.59166091188422
# itération: 133 reward: -108.32787759877246
# itération: 134 reward: -134.86239946113625
# itération: 135 reward: -121.83373650883205
# itération: 136 reward: -202.93317355517252
# itération: 137 reward: -132.09789232044292
# -138.72516293902987
# itération: 138 reward: -4.419914484455404
# itération: 139 reward: -152.6769186677111
# itération: 140 reward: -134.10297493107907
# itération: 141 reward: -165.56724988062018
# itération: 142 reward: -122.76598333675466
# itération: 143 reward: -108.01986867836092
# itération: 144 reward: -121.20525610820776
# itération: 145 reward: -103.35291961822388
# itération: 146 reward: -114.29928914572169
# itération: 147 reward: -126.36001845057586
# itération: 148 reward: -111.61894790730682
# itération: 149 reward: -158.84743348876145
# itération: 150 reward: -196.71155380919038
# itération: 151 reward: 30.875480972339375
# itération: 152 reward: -154.07436816177778
# itération: 153 reward: -72.03204040108554
# itération: 154 reward: -175.98031376498486
# itération: 155 reward: -137.1991718205811
# itération: 156 reward: -156.27802968902296
# itération: 157 reward: -84.92595266051154
# itération: 158 reward: -116.63336970358819
# itération: 159 reward: -193.34413236562153
# itération: 160 reward: -97.58685424327277
# itération: 161 reward: -141.84724961276424
# itération: 162 reward: -131.0114537566595
# itération: 163 reward: -138.21412776628864
# itération: 164 reward: -132.39154418385542
# itération: 165 reward: -170.4444440992642
# itération: 166 reward: -130.97854766120142
# itération: 167 reward: -92.58349871003318
# itération: 168 reward: -178.4657555807578
# itération: 169 reward: -161.92409644856173
# itération: 170 reward: -135.76389995772993
# itération: 171 reward: -121.41864329032678
# itération: 172 reward: -167.40896603048415
# itération: 173 reward: -87.99987766611781
# itération: 174 reward: -105.88783533617664
# itération: 175 reward: 21.668611365130857
# itération: 176 reward: -127.9159772794614
# itération: 177 reward: -117.88756465960546
# itération: 178 reward: -19.091531365406382
# itération: 179 reward: -136.35799916468648
# itération: 180 reward: -48.653055508637244
# itération: 181 reward: -4.454334650336818
# itération: 182 reward: -114.2724633901882
# itération: 183 reward: -129.64640080884277
# itération: 184 reward: -80.17780392907449
# itération: 185 reward: -160.11524785239507
# itération: 186 reward: -191.14797971491788
# itération: 187 reward: -127.88016921447642
# itération: 188 reward: -88.20185027018584
# itération: 189 reward: -128.4653864736048
# itération: 190 reward: -134.70774937761863
# itération: 191 reward: -135.95093759920925
# itération: 192 reward: -87.8208621181437
# itération: 193 reward: -118.11937165527591
# itération: 194 reward: -91.30469468913006
# itération: 195 reward: -121.24231348242377
# itération: 196 reward: -145.66972176415894
# itération: 197 reward: -137.67576302354234
# itération: 198 reward: -110.2139617638349
# itération: 199 reward: -137.78911061027884
# itération: 200 reward: -129.57020585198376
# itération: 201 reward: -118.28664648185433
# itération: 202 reward: -266.51590140120123
# itération: 203 reward: -115.96856227771119
# itération: 204 reward: -188.98415218489515
# itération: 205 reward: -90.43165890132127
# itération: 206 reward: -55.12409585708269
# itération: 207 reward: -150.38132886854004
# itération: 208 reward: -153.14558364738576
# itération: 209 reward: -150.69650584027434
# itération: 210 reward: -125.46991697926654
# itération: 211 reward: -301.2516188156862
# itération: 212 reward: -178.84618766619792
# itération: 213 reward: -140.8529315326693
# itération: 214 reward: -167.81796710337267
# itération: 215 reward: -156.4879306214823
# itération: 216 reward: -147.20645705113193
# itération: 217 reward: -142.05616563196952
# itération: 218 reward: -83.69702066493562
# itération: 219 reward: -98.73958447932043
# itération: 220 reward: -117.64156570013876
# itération: 221 reward: -168.909557616199
# itération: 222 reward: -132.32521095078312
# itération: 223 reward: -160.87393829298696
# itération: 224 reward: -108.03607255632662
# itération: 225 reward: -192.90450771254405
# itération: 226 reward: -126.15534023513126
# itération: 227 reward: -137.94670152295976
# itération: 228 reward: -137.29009766453515
# itération: 229 reward: -122.40813664186282
# itération: 230 reward: 13.158000125758605
# itération: 231 reward: -168.13571771142603
# itération: 232 reward: -128.96385002132044
# itération: 233 reward: -147.9857831841147
# itération: 234 reward: -111.21692430147607
# itération: 235 reward: -108.60958129295375
# itération: 236 reward: -114.71435560305417
# itération: 237 reward: -112.6379415030624
# itération: 238 reward: -142.66361995877088
# itération: 239 reward: -135.92611486183858
# itération: 240 reward: -172.63585287666794
# itération: 241 reward: -186.72947737894248
# itération: 242 reward: -109.53033873765554
# itération: 243 reward: -108.78083342904134
# itération: 244 reward: -106.04220991002428
# itération: 245 reward: -173.51396630797595
# itération: 246 reward: -149.67374570993474
# itération: 247 reward: -98.004012596199
# -164.32956209252842
# itération: 248 reward: -103.66970272955362
# itération: 249 reward: -120.85489986653944
# itération: 250 reward: -137.18567472498694
# itération: 251 reward: -136.2670969836305
# itération: 252 reward: -103.1647339223428
# itération: 253 reward: -156.1125980809161
# itération: 254 reward: -111.57571071370322
# itération: 255 reward: -142.10172743465964
# itération: 256 reward: -135.59988269376478
# itération: 257 reward: -122.76882843880648
# itération: 258 reward: -114.25941204359779
# itération: 259 reward: -153.15781510480926
# itération: 260 reward: -108.08499210661995
# itération: 261 reward: -106.69189240830624
# itération: 262 reward: -113.97559903763309
# itération: 263 reward: -122.45695265352188
# itération: 264 reward: -160.4824679291475
# itération: 265 reward: -175.97359592044774
# -145.9011769704434
# itération: 266 reward: -116.51075816380542
# itération: 267 reward: -215.22601762910483
# itération: 268 reward: -145.28820985616647
# itération: 269 reward: -123.95260499500506
# itération: 270 reward: -145.19861520611846
# itération: 271 reward: -110.89351539388687
# itération: 272 reward: -83.16825761171614
# itération: 273 reward: -229.81020200002547
# itération: 274 reward: -124.16771341560755
# itération: 275 reward: -156.69012279293577
# itération: 276 reward: -138.86358193325265
# itération: 277 reward: -447.5165232635056
# itération: 278 reward: -122.15891032136973
# itération: 279 reward: -108.06670523835113
# itération: 280 reward: -136.61063768214
# itération: 281 reward: 28.557379022672677
# itération: 282 reward: -138.53076483434975
# itération: 283 reward: -138.90775638785658
# itération: 284 reward: -133.2128318692861
# itération: 285 reward: -130.58099836501395
# itération: 286 reward: -245.71580183929947
# itération: 287 reward: -113.4182413557936
# itération: 288 reward: -163.0997400244304
# itération: 289 reward: -139.29512046323396
# itération: 290 reward: -128.64627376553352
# itération: 291 reward: -0.4236141276355312
# itération: 292 reward: -141.87212605102405
# itération: 293 reward: -112.65829464169659
# itération: 294 reward: -148.21052434292244
# itération: 295 reward: -141.46433655589817
# itération: 296 reward: -138.89093251490394
# itération: 297 reward: -116.54082051636087
# itération: 298 reward: -154.95600007532403
# itération: 299 reward: -119.79014959182604
# itération: 300 reward: -108.43253662776763
# itération: 301 reward: -123.99190513325988
# itération: 302 reward: -124.09867212163793
# itération: 303 reward: -90.63499783430008
# itération: 304 reward: -154.3186674298055
# itération: 305 reward: -128.65674450556457
# itération: 306 reward: -97.40103004420911
# itération: 307 reward: -86.87706329422144
# itération: 308 reward: -173.4705300547194
# itération: 309 reward: 17.79809041166763
# itération: 310 reward: -128.48316687999622
# itération: 311 reward: -100.25757512805913
# itération: 312 reward: -299.3478441774629
# itération: 313 reward: -128.49045035510733
# itération: 314 reward: -236.1485701925969
# itération: 315 reward: -125.04703533090338
# itération: 316 reward: -453.28357987242657
# itération: 317 reward: -64.65381800450874
# itération: 318 reward: -105.66336807537286
# itération: 319 reward: -159.22088946751583
# itération: 320 reward: -131.07695620938748
# itération: 321 reward: -81.40619298512902
# itération: 322 reward: -143.43929479470097
# itération: 323 reward: -122.20976137306981
# itération: 324 reward: -100.58285425066447
# itération: 325 reward: -91.04830571483944
# itération: 326 reward: -480.7086272392776
# itération: 327 reward: -118.25302682055067
# itération: 328 reward: -171.50090742707897
# itération: 329 reward: -89.95094826120643
# itération: 330 reward: -114.71363131574572
# itération: 331 reward: -16.697700290055735
# itération: 332 reward: -535.5258271473778
# itération: 333 reward: -68.25775879222695
# itération: 334 reward: -144.2473305354407
# itération: 335 reward: -92.83838947893346
# itération: 336 reward: -93.56313374511822
# itération: 337 reward: -146.58925463342237
# itération: 338 reward: -156.38371918160217
# itération: 339 reward: -163.32751286339283
# itération: 340 reward: -180.80920471936375
# itération: 341 reward: -136.33468495135025
# itération: 342 reward: -163.50725417845243
# itération: 343 reward: -120.65226787583896
# itération: 344 reward: -127.75010148421866
# itération: 345 reward: -130.87489864254917
# itération: 346 reward: -132.14229039421576
# itération: 347 reward: -95.73206828870059
# itération: 348 reward: -109.7954457992241
# itération: 349 reward: -121.41497002721758
# itération: 350 reward: -107.95795727651918
# itération: 351 reward: -413.24665259426155
# itération: 352 reward: -117.54685722651959
# itération: 353 reward: -120.07425390992415
# itération: 354 reward: -147.49231618764523
# itération: 355 reward: -112.48538391628699
# itération: 356 reward: -198.21722892928037
# itération: 357 reward: -126.61585058685506
# itération: 358 reward: -124.83842137159388
# itération: 359 reward: -136.28926372766384
# itération: 360 reward: -115.6535220013046
# itération: 361 reward: -138.13538240438228
# itération: 362 reward: -113.60581438470871
# itération: 363 reward: -126.0364130445677
# itération: 364 reward: -130.11761486501828
# itération: 365 reward: -145.31492715242965
# -140.8501893831213
# itération: 366 reward: -126.46916832897371
# itération: 367 reward: -5.109662652196647
# itération: 368 reward: -114.18478999127137
# itération: 369 reward: -95.75904319679528
# itération: 370 reward: -140.4001098130127
# itération: 371 reward: -119.88286982973494
# itération: 372 reward: -88.66675779128818
# itération: 373 reward: -178.1256679387302
# itération: 374 reward: -134.92607404303715
# itération: 375 reward: -97.00706604593756
# itération: 376 reward: -100.06100355786216
# itération: 377 reward: -107.77278113478232
# itération: 378 reward: -125.31410828176838
# itération: 379 reward: -114.91326770036424
# itération: 380 reward: -185.76991383159017
# itération: 381 reward: -133.1076392425425
# itération: 382 reward: -112.57736439640098
# itération: 383 reward: -109.20063480760757
# itération: 384 reward: -108.52168060841218
# itération: 385 reward: -130.542538244893
# itération: 386 reward: -144.19427232561077
# itération: 387 reward: -117.34307567989522
# itération: 388 reward: -114.69095646171226
# itération: 389 reward: -144.4083315813874
# itération: 390 reward: 19.21100463462618
# itération: 391 reward: -114.4001802036704
# itération: 392 reward: -94.55812542754929
# itération: 393 reward: -97.1588335570082
# itération: 394 reward: -160.58473883086276
# itération: 395 reward: -133.24853778583045
# itération: 396 reward: -138.08812612158607
# itération: 397 reward: -97.94999353896236
# itération: 398 reward: -212.0540895737069
# itération: 399 reward: -124.17739080588737
# itération: 400 reward: -115.30948998619317
# itération: 401 reward: -121.74586368780771
# itération: 402 reward: -101.29730087774664
# itération: 403 reward: -125.03013809246733
# itération: 404 reward: -94.87334675915451
# itération: 405 reward: -123.51983417365895
# -90.40646446500149
# itération: 406 reward: -126.26326877969251
# itération: 407 reward: -83.54743037327836
# itération: 408 reward: -147.27137216762037
# itération: 409 reward: -99.81468075181749
# itération: 410 reward: 20.851727851175028
# itération: 411 reward: -117.28662877961798
# itération: 412 reward: -93.76063323226981
# itération: 413 reward: -149.8893967264371
# itération: 414 reward: -125.31309630816344
# itération: 415 reward: -140.6708566230053
# itération: 416 reward: -8.987547631139563
# itération: 417 reward: -318.0409180842305
# itération: 418 reward: -118.8110189443945
# itération: 419 reward: -166.47901371222846
# itération: 420 reward: 5.628779634396707
# itération: 421 reward: -127.86978268983677
# itération: 422 reward: -104.08863880224717
# itération: 423 reward: -128.44594746955565
# itération: 424 reward: -174.41357690450866
# itération: 425 reward: -132.6182054551171
# itération: 426 reward: -150.35369038304157
# itération: 427 reward: -137.37529761337706
# itération: 428 reward: -131.32623351210276
# itération: 429 reward: -97.86820314380358
# itération: 430 reward: -121.83818523191556
# itération: 431 reward: -98.88367906431245
# itération: 432 reward: -137.81158919463735
# itération: 433 reward: -96.81270713925748
# itération: 434 reward: -149.47512313558562
# itération: 435 reward: 18.076178383856217
# itération: 436 reward: -18.976079431696178
# itération: 437 reward: -133.71824149346202
# itération: 438 reward: -91.29378563840106
# itération: 439 reward: -88.93074520819593
# itération: 440 reward: -125.2171820968683
# itération: 441 reward: -90.42562395031467
# itération: 442 reward: -107.99567011427044
# itération: 443 reward: -54.040727439911095
# itération: 444 reward: -165.2763628749671
# itération: 445 reward: -168.49906006135376
# itération: 446 reward: -120.73387755644941
# itération: 447 reward: -93.74102188844384
# itération: 448 reward: -177.0292333526037
# itération: 449 reward: -136.87010493624422
# itération: 450 reward: -153.08697458292008
# itération: 451 reward: -331.4722241989531
# itération: 452 reward: -121.41603847907902
# itération: 453 reward: -129.9564861290646
# itération: 454 reward: -101.95116118693772
# itération: 455 reward: -126.79217174893098
# itération: 456 reward: -118.1574944330039
# itération: 457 reward: -191.98932238844046
# itération: 458 reward: -108.72114852421416
# itération: 459 reward: -128.71387927444624
# itération: 460 reward: -141.34546933792834
# itération: 461 reward: -156.3180864404733
# itération: 462 reward: -122.23721068752818
# itération: 463 reward: 30.02864489323582
# itération: 464 reward: -234.46064779738782
# itération: 465 reward: -137.99718146947447
# itération: 466 reward: -170.48004780978198
# itération: 467 reward: -106.22950453367918
# itération: 468 reward: -127.68259041218911
# itération: 469 reward: -138.5477621813353
# itération: 470 reward: -109.49655278152017
# itération: 471 reward: -108.07114702298398
# itération: 472 reward: -286.56878671619717
# itération: 473 reward: 24.00713105648795
# itération: 474 reward: -331.2322302957111
# itération: 475 reward: -109.89747808417232
# itération: 476 reward: -286.3405966834164
# itération: 477 reward: -157.9331660330128
# itération: 478 reward: -81.10909615176583
# itération: 479 reward: -361.7832969395513
# itération: 480 reward: -110.49661320157453
# itération: 481 reward: -135.7763868566782
# itération: 482 reward: 15.72059658167936
# itération: 483 reward: -19.340790638852127
# itération: 484 reward: -182.52577543900338
# itération: 485 reward: -125.82848179034636
# itération: 486 reward: -120.3003001310626
# itération: 487 reward: -121.13593619076238
# itération: 488 reward: -191.53694241743844
# itération: 489 reward: -51.87010747420727
# itération: 490 reward: -135.11572047460567
# itération: 491 reward: -144.3302663535234
# itération: 492 reward: -148.77672393009738
# itération: 493 reward: -119.61445416460981
# -115.95787303325758
# itération: 494 reward: -123.68108451968376
# itération: 495 reward: -109.08889584883772
# itération: 496 reward: -115.75340259724476
# itération: 497 reward: -135.34134886175218
# itération: 498 reward: -132.27051957533808
# itération: 499 reward: -121.3640253536786
# itération: 500 reward: -148.94780692925644
# itération: 501 reward: -108.8749971432504
# itération: 502 reward: -121.7251999084565
# itération: 503 reward: -93.13987098090519
# itération: 504 reward: -152.28404660915848
# itération: 505 reward: -118.6109375471824
# itération: 506 reward: -104.18691877872922
# itération: 507 reward: 7.545004668498834
# itération: 508 reward: -103.61302862481799
# itération: 509 reward: -109.9179799804316
# itération: 510 reward: -110.8455130143241
# itération: 511 reward: -136.1509804336419
# itération: 512 reward: -142.29707245575503
# itération: 513 reward: -99.12467152745968
# itération: 514 reward: -149.34732826230845
# itération: 515 reward: -157.74944913553264
# itération: 516 reward: -154.19425594260102
# itération: 517 reward: -154.3327930715484
# itération: 518 reward: -116.0154332854199
# itération: 519 reward: -150.1917075063796
# itération: 520 reward: -130.19583307117173
# itération: 521 reward: -105.93299285166316
# itération: 522 reward: -175.1697211666326
# itération: 523 reward: -118.17690005902966
# itération: 524 reward: -362.82220735860415
# itération: 525 reward: -111.54568567160538
# itération: 526 reward: -146.84639924618637
# itération: 527 reward: -109.68978125719696
# itération: 528 reward: -107.98420100346257
# itération: 529 reward: -120.83217426308215
# itération: 530 reward: -155.51670035517336
# itération: 531 reward: -111.65220519240054
# itération: 532 reward: -103.31151228508614
# itération: 533 reward: -89.45577119512603
# itération: 534 reward: -162.07885383820212
# itération: 535 reward: -156.87358809100803
# itération: 536 reward: -152.7063237464565
# itération: 537 reward: -76.87236803258196
# itération: 538 reward: -143.41464074802207
# itération: 539 reward: -115.97363673641314
# itération: 540 reward: -128.54154607804364
# itération: 541 reward: -119.2850304255501
# itération: 542 reward: -123.95589658283296
# itération: 543 reward: -146.9990338011366
# itération: 544 reward: -109.39512209310419
# itération: 545 reward: -135.14893770331162
# itération: 546 reward: -127.05384269609888
# itération: 547 reward: -92.44726195062088
# itération: 548 reward: -121.49104239821773
# itération: 549 reward: -142.8448876759945
# itération: 550 reward: -120.70393542508927
# itération: 551 reward: -128.69310432465628
# itération: 552 reward: -129.28594862855257
# itération: 553 reward: -136.59399485067408
# itération: 554 reward: -132.53612246549767
# itération: 555 reward: -145.06142453770303
# itération: 556 reward: -141.93271250817412
# itération: 557 reward: -167.81527443973602
# itération: 558 reward: -97.82370382659842
# itération: 559 reward: -158.90360796029282
# itération: 560 reward: -148.7850150744457
# itération: 561 reward: -72.92273966434871
# itération: 562 reward: -120.97621231884284
# itération: 563 reward: -105.23478402664773
# itération: 564 reward: -26.725061583366497
# itération: 565 reward: -128.83162821533858
# itération: 566 reward: -109.98008317484873
# itération: 567 reward: -12.621062900012703
# itération: 568 reward: -176.5968182193229
# itération: 569 reward: -98.26871719431
# itération: 570 reward: -124.90092562279239
# itération: 571 reward: -157.44237484248043
# itération: 572 reward: -134.48922811859265
# itération: 573 reward: -196.16620900714213
# -136.9645154047235
# itération: 574 reward: -138.5627083037411
# itération: 575 reward: -114.36918280134668
# itération: 576 reward: -111.5722981530979
# itération: 577 reward: -97.05497580110551
# itération: 578 reward: -112.07063221742175
# itération: 579 reward: -101.56326801298431
# itération: 580 reward: -112.22553879045134
# itération: 581 reward: -108.21945158468097
# itération: 582 reward: -41.57069119042097
# itération: 583 reward: -146.7667760923136
# itération: 584 reward: -124.89526119815977
# itération: 585 reward: -95.92556856970293
# itération: 586 reward: -118.34555060831721
# itération: 587 reward: -121.84898089701016
# itération: 588 reward: -152.5712544435944
# itération: 589 reward: -112.65208179742413
# itération: 590 reward: -89.17968957029774
# itération: 591 reward: -63.14486396936594
# itération: 592 reward: -123.3185339505859
# itération: 593 reward: -149.352050822354
# itération: 594 reward: -55.76397162371173
# itération: 595 reward: -120.32810490968083
# itération: 596 reward: -134.63960031929437
# itération: 597 reward: -256.1205903043065
# itération: 598 reward: -137.81853087476412
# itération: 599 reward: -232.942503010729
# itération: 600 reward: -101.23128992289179
# itération: 601 reward: -119.38411643195167
# itération: 602 reward: -79.73391200629342
# itération: 603 reward: 11.353203745966951
# itération: 604 reward: -114.0496325612105
# itération: 605 reward: -87.03759807186418
# itération: 606 reward: -151.39509825865602
# itération: 607 reward: -252.47946252187324
# itération: 608 reward: -90.87267088433805
# itération: 609 reward: -108.73572482198443
# itération: 610 reward: -112.92053361912781
# itération: 611 reward: -120.44085529513944
# itération: 612 reward: -118.68932078888736
# itération: 613 reward: -151.13964925323066
# itération: 614 reward: -158.9082459617831
# itération: 615 reward: -101.72746910233982
# itération: 616 reward: -128.29893962305295
# itération: 617 reward: -158.33421292326918
# itération: 618 reward: -93.93986438394884
# itération: 619 reward: -92.80787117354998
# itération: 620 reward: -131.71291138160606
# itération: 621 reward: -105.29515695483386
# itération: 622 reward: -105.8156548328302
# itération: 623 reward: -132.55495268115382
# itération: 624 reward: -165.54314092208875
# itération: 625 reward: -105.61985743337982
# itération: 626 reward: -93.1724387983456
# itération: 627 reward: -178.98001378944383
# itération: 628 reward: -107.50032930426158
# itération: 629 reward: -94.1907652622646
# itération: 630 reward: -133.83532310228955
# itération: 631 reward: -87.61052773551555
# itération: 632 reward: -110.58703476493963
# itération: 633 reward: -75.87677047306651
# itération: 634 reward: -109.02612120049355
# itération: 635 reward: -99.65886237245452
# itération: 636 reward: -126.2784884191318
# itération: 637 reward: -80.92591417036859
# itération: 638 reward: -137.47121459432063
# itération: 639 reward: -157.9075946448571
# itération: 640 reward: -144.66101172179935
# itération: 641 reward: -118.38451205324367
# itération: 642 reward: -96.7647859989442
# itération: 643 reward: -119.25292473897207
# itération: 644 reward: -101.80630930381028
# itération: 645 reward: -127.97439604425031
# itération: 646 reward: -110.03303874158445
# itération: 647 reward: -184.93977436146253
# itération: 648 reward: -101.80040263565343
# itération: 649 reward: -146.14615604394882
# itération: 650 reward: -130.8053586568227
# itération: 651 reward: -106.63235217104771
# itération: 652 reward: -170.02764554262845
# itération: 653 reward: -124.12269874702858
# itération: 654 reward: -104.84356313133301
# itération: 655 reward: -163.73125244080802
# itération: 656 reward: -123.53271795488888
# itération: 657 reward: -149.39574891422785
# itération: 658 reward: -89.03740567641871
# itération: 659 reward: -84.8723049819223
# itération: 660 reward: -118.34901668066661
# itération: 661 reward: -103.26283014444553
# itération: 662 reward: -141.66800911900035
# itération: 663 reward: -100.35277979189141
# itération: 664 reward: -94.53927177139033
# itération: 665 reward: -105.85403629286031
# itération: 666 reward: -128.65150911376134
# itération: 667 reward: -161.28231973665532
# itération: 668 reward: -78.5021765598248
# itération: 669 reward: -128.1110663032048
# itération: 670 reward: -97.37213866543489
# itération: 671 reward: -149.99103557950332
# itération: 672 reward: -118.03889789665112
# itération: 673 reward: -175.5737777715217
# itération: 674 reward: 22.204662986712066
# itération: 675 reward: 29.65775431204935
# itération: 676 reward: -128.8304931954049
# itération: 677 reward: -155.47502388585286
# itération: 678 reward: -140.9428597575622
# itération: 679 reward: -124.65234621693827
# itération: 680 reward: -125.30593710235425
# itération: 681 reward: -139.6065060696857
# itération: 682 reward: -126.13670179257048
# itération: 683 reward: -98.70524936352007
# itération: 684 reward: -128.9010074342244
# itération: 685 reward: -134.7028087401163
# itération: 686 reward: -86.50828988900231
# itération: 687 reward: -96.3695908212657
# itération: 688 reward: -131.1311955520153
# itération: 689 reward: -139.9329488588717
# itération: 690 reward: -136.50603586855695
# itération: 691 reward: -121.36128118795861
# itération: 692 reward: -142.75681780703871
# itération: 693 reward: -330.82759273081336
# itération: 694 reward: -118.30338601500955
# itération: 695 reward: -158.38702094069487
# itération: 696 reward: -130.89440917383635
# itération: 697 reward: -165.08840997147956
# itération: 698 reward: -155.00651831566003
# itération: 699 reward: -86.10942568046038
# itération: 700 reward: -85.76478229348508
# itération: 701 reward: -139.82238995898996
# itération: 702 reward: -105.71069294649766
# itération: 703 reward: -14.191802935630136
# itération: 704 reward: -120.57933023730763
# itération: 705 reward: -140.52412272033024
# itération: 706 reward: -102.93931019306291
# itération: 707 reward: -97.06132501719391
# itération: 708 reward: -30.802690568367353
# itération: 709 reward: -122.27787984461236
# itération: 710 reward: -105.45427143929705
# itération: 711 reward: -132.2264432171716
# itération: 712 reward: -187.61536051881887
# itération: 713 reward: -113.78748737204637
# itération: 714 reward: -142.47084809223048
# itération: 715 reward: -136.69668404011702
# itération: 716 reward: -99.189189832393
# itération: 717 reward: -110.49582607805901
# itération: 718 reward: -181.50044111494623
# itération: 719 reward: -155.72800819486227
# itération: 720 reward: -114.01329243015354
# itération: 721 reward: -87.41298639420458
# itération: 722 reward: -89.89982661134782
# itération: 723 reward: -114.12683742526758
# itération: 724 reward: -128.65807544038813
# itération: 725 reward: -173.04416759152758
# itération: 726 reward: -72.13973482653239
# itération: 727 reward: -122.96353482511009
# itération: 728 reward: 6.634771618613598
# itération: 729 reward: -113.49203261441203
# itération: 730 reward: -90.20290127474465
# itération: 731 reward: -116.96446127023842
# itération: 732 reward: -120.31374763595221
# itération: 733 reward: -122.64367718575066
# itération: 734 reward: -126.20898420396637
# itération: 735 reward: -137.08252742487468
# itération: 736 reward: -114.77232786170998
# itération: 737 reward: -279.77949556519746
# itération: 738 reward: -146.21113359213115
# itération: 739 reward: -155.67727665536722
# itération: 740 reward: -137.8724830062574
# itération: 741 reward: -176.4867773249297
# itération: 742 reward: -131.5943730415891
# itération: 743 reward: -97.16270825751053
# itération: 744 reward: -318.16263222864546
# itération: 745 reward: -115.9794126814794
# itération: 746 reward: -137.2425412814229
# itération: 747 reward: -106.0360166281666
# itération: 748 reward: -98.07842725250774
# itération: 749 reward: -90.4113748920638
# itération: 750 reward: -129.08553380366234
# itération: 751 reward: -193.02362929520444
# itération: 752 reward: -108.06069136543758
# itération: 753 reward: -68.95977015193404
# itération: 754 reward: -181.23091295181737
# itération: 755 reward: -71.10143322034327
# -83.52750705023288
# itération: 756 reward: -104.77214629351036
# itération: 757 reward: -138.39547762604727
# itération: 758 reward: -185.91795155602344
# itération: 759 reward: -125.31259915761768
# itération: 760 reward: -145.85483557084123
# itération: 761 reward: -104.69820446022675
# itération: 762 reward: -105.48717533903982
# itération: 763 reward: -119.03422140060279
# itération: 764 reward: -196.23839222861253
# itération: 765 reward: -44.53892962270973
# itération: 766 reward: -170.72844787515774
# itération: 767 reward: -90.88891332144976
# itération: 768 reward: -136.16909862857744
# itération: 769 reward: -182.59461179867867
# itération: 770 reward: -61.53221839741582
# itération: 771 reward: -291.6353895073464
# itération: 772 reward: -124.38996015216804
# itération: 773 reward: -67.91391787516898
# itération: 774 reward: -110.37415004895726
# itération: 775 reward: -83.84338358060603
# itération: 776 reward: -177.1504594887187
# itération: 777 reward: -134.05714950294995
# itération: 778 reward: -138.04276933687257
# itération: 779 reward: -111.18558613787187
# itération: 780 reward: -121.27217211762482
# itération: 781 reward: -99.8798918349046
# itération: 782 reward: -58.900341156126444
# itération: 783 reward: -125.2025627821244
# itération: 784 reward: -157.76565101389505
# itération: 785 reward: -123.82547517538512
# itération: 786 reward: -156.15570510192495
# itération: 787 reward: -279.86452191497096
# itération: 788 reward: -118.19860688563952
# itération: 789 reward: -77.98555311888589
# itération: 790 reward: 27.180440620028122
# itération: 791 reward: -132.957245533274
# itération: 792 reward: -85.42953644119721
# itération: 793 reward: -170.9698750726688
# itération: 794 reward: -173.85552882419267
# itération: 795 reward: -46.97516790887201
# itération: 796 reward: -138.40219797954538
# itération: 797 reward: -97.98641972127513
# itération: 798 reward: -103.7775438464669
# itération: 799 reward: -76.78102809340521
# itération: 800 reward: -367.72035693055057
# itération: 801 reward: -83.32267596516655
# itération: 802 reward: -121.82393141791965
# itération: 803 reward: -96.64276643462352
# itération: 804 reward: -107.00320893293681
# itération: 805 reward: -113.24087631532542
# itération: 806 reward: -139.24396615318219
# itération: 807 reward: -122.89518595040983
# itération: 808 reward: -96.96584991019822
# itération: 809 reward: -85.20272539413685
# itération: 810 reward: -110.53094024114131
# itération: 811 reward: -107.3721249735408
# itération: 812 reward: -110.60444244758042
# itération: 813 reward: -155.04543931369327
# itération: 814 reward: -100.4868819670186
# itération: 815 reward: -90.52238787737646
# itération: 816 reward: -78.8771167274065
# itération: 817 reward: -296.10973955081056
# itération: 818 reward: -275.76906991019945
# itération: 819 reward: -263.74200745931034
# itération: 820 reward: -99.3682782380796
# itération: 821 reward: -293.1369676298061
# itération: 822 reward: -103.86273561497815
# itération: 823 reward: -254.68923005672764
# itération: 824 reward: -285.46833719440565
# itération: 825 reward: -116.78256277751133
# itération: 826 reward: -94.4488077272928
# itération: 827 reward: -255.7373562617712
# itération: 828 reward: -101.93781327311578
# itération: 829 reward: -275.98645255598564
# itération: 830 reward: -226.16880144524652
# itération: 831 reward: -243.43113382744173
# itération: 832 reward: -97.638370472678
# itération: 833 reward: -120.8587338566797
# itération: 834 reward: -230.23857835977486
# itération: 835 reward: -172.32187755916104
# itération: 836 reward: -71.85092870552913
# itération: 837 reward: -114.6006289353754
# itération: 838 reward: -108.3349870134674
# itération: 839 reward: -100.07099379168183
# itération: 840 reward: -152.02473967702366
# itération: 841 reward: -103.65102100669678
# itération: 842 reward: -112.08077946875451
# itération: 843 reward: -94.56084893906518
# itération: 844 reward: -137.328843266023
# itération: 845 reward: -118.36772054377283
# itération: 846 reward: -108.4449722064467
# itération: 847 reward: -290.3136366467087
# itération: 848 reward: -86.121271613298
# itération: 849 reward: -130.90931062689336
# itération: 850 reward: -110.27486164719011
# itération: 851 reward: -91.8323946932926
# itération: 852 reward: -227.55710225408754
# itération: 853 reward: -103.72003063276564
# itération: 854 reward: -146.9453860916338
# itération: 855 reward: -101.65385539494606
# itération: 856 reward: -228.58384342913314
# itération: 857 reward: -267.86552291567824
# itération: 858 reward: -115.6856526643619
# itération: 859 reward: -75.09957378495281
# itération: 860 reward: -189.11789746379202
# itération: 861 reward: -87.84176914344818
# itération: 862 reward: -234.10295841928541
# itération: 863 reward: -263.11807355153087
# itération: 864 reward: -309.27228274389535
# itération: 865 reward: -252.4108251801439
# itération: 866 reward: -128.20235097406277
# itération: 867 reward: -97.63715567706447
# itération: 868 reward: -180.89414341952408
# itération: 869 reward: -291.32115858366495
# itération: 870 reward: -102.31114016558678
# itération: 871 reward: -93.28666823317437
# itération: 872 reward: -79.37990529528678
# itération: 873 reward: -86.13440280904919
# itération: 874 reward: -133.16401849419364
# itération: 875 reward: -110.27857181704873
# itération: 876 reward: -309.4754476189792
# itération: 877 reward: -272.50094287368285
# itération: 878 reward: -81.05103930160413
# itération: 879 reward: -127.54285178318409
# itération: 880 reward: -102.57211001321005
# itération: 881 reward: -94.90540234165665
# itération: 882 reward: -126.76750561680564
# itération: 883 reward: -124.62794155410728
# itération: 884 reward: -147.02291002200587
# itération: 885 reward: -100.60377507853244
# itération: 886 reward: -109.60143660905453
# itération: 887 reward: -82.25557521613483
# itération: 888 reward: -71.68410497587514
# itération: 889 reward: -22.074589308253934
# itération: 890 reward: -161.00982209696235
# itération: 891 reward: -160.95197961888388
# itération: 892 reward: -126.95824381374882
# itération: 893 reward: -109.69177956255072
# itération: 894 reward: -21.86887030695516
# itération: 895 reward: -74.50885063367826
# itération: 896 reward: -84.42364745541833
# itération: 897 reward: -181.50591342206127
# itération: 898 reward: -130.34042121995287
# itération: 899 reward: -168.29096986291506
# -269.88831166655433
# itération: 900 reward: -76.83210896406969
# itération: 901 reward: -64.28992585349857
# itération: 902 reward: -84.39271286762758
# itération: 903 reward: -88.20412780049861
# itération: 904 reward: -146.2906333314764
# itération: 905 reward: -101.24239753886228
# itération: 906 reward: -138.24407781447877
# itération: 907 reward: -124.4414957570734
# itération: 908 reward: -103.99347771358651
# itération: 909 reward: -146.45994416713256
# itération: 910 reward: -129.07586426491915
# itération: 911 reward: -122.69373413377022
# itération: 912 reward: -32.862936124565934
# itération: 913 reward: -96.97812310016141
# itération: 914 reward: -118.37230709340746
# itération: 915 reward: -146.5813456800373
# itération: 916 reward: -131.45655788451106
# itération: 917 reward: -131.6892734272628
# itération: 918 reward: -131.89144891548352
# itération: 919 reward: -205.9032741200778
# itération: 920 reward: -125.53213968166023
# itération: 921 reward: -90.61857837006244
# itération: 922 reward: -79.8856269016611
# itération: 923 reward: -267.41205675305275
# itération: 924 reward: -325.9506897285745
# itération: 925 reward: -272.5613448995897
# itération: 926 reward: -217.35234961647694
# itération: 927 reward: -207.92899538668325
# itération: 928 reward: -86.92972692968704
# itération: 929 reward: -78.57591585973208
# itération: 930 reward: -153.40404335394828
# itération: 931 reward: -257.2607849609497
# itération: 932 reward: -281.6174972044982
# itération: 933 reward: -94.67917663431064
# itération: 934 reward: -83.63964012411202
# itération: 935 reward: -102.90481656174263
# itération: 936 reward: -109.36128619280379
# itération: 937 reward: -89.69240873743686
# itération: 938 reward: -164.43936729589058
# itération: 939 reward: -183.91932467568347
# itération: 940 reward: -198.36011612030194
# itération: 941 reward: -84.69212619558401
# itération: 942 reward: -223.4032799023904
# itération: 943 reward: -236.61250058760697
# itération: 944 reward: -266.58020837897084
# itération: 945 reward: -226.74406216487884
# itération: 946 reward: -274.59603097968767
# itération: 947 reward: -264.7172234476785
# itération: 948 reward: -101.28238495937055
# itération: 949 reward: -115.50613039422586
# itération: 950 reward: -145.14801140942444
# itération: 951 reward: -166.2726877624073
# itération: 952 reward: -115.1165403842766
# itération: 953 reward: -110.67197988865499
# itération: 954 reward: -124.92429214658662
# itération: 955 reward: -116.42174717508394
# itération: 956 reward: -104.50633286231232
# itération: 957 reward: -153.11870888685542
# itération: 958 reward: -111.52007930369426
# itération: 959 reward: -92.45853332716736
# itération: 960 reward: -116.40417939011432
# itération: 961 reward: 23.462143551937345
# itération: 962 reward: -90.68710793594936
# itération: 963 reward: -195.42976868244097
# itération: 964 reward: -229.02264450441618
# itération: 965 reward: -252.02840697214384
# itération: 966 reward: -82.54457342595347
# itération: 967 reward: -153.92489372356908
# itération: 968 reward: -65.83826053413726
# itération: 969 reward: -301.5629508343907
# itération: 970 reward: -59.72377251952423
# itération: 971 reward: -137.07658730230762
# itération: 972 reward: -116.11744509418651
# itération: 973 reward: -233.46542917305112
# itération: 974 reward: -92.09690198811634
# itération: 975 reward: -150.72974060998916
# itération: 976 reward: -213.70434526036317
# itération: 977 reward: -263.45509428356513
# itération: 978 reward: -239.57814235373078
# itération: 979 reward: -278.08080949875733
# itération: 980 reward: -152.65723200487324
# itération: 981 reward: -119.74025879550337
# itération: 982 reward: -129.7192037569617
# itération: 983 reward: -271.7080523937923
# itération: 984 reward: -114.95773724602765
# itération: 985 reward: -200.12642475555865
# itération: 986 reward: -45.23080006247446
# itération: 987 reward: -243.58177993459174
# itération: 988 reward: -215.99205527519956
# itération: 989 reward: -245.55181332728017
# itération: 990 reward: -222.19276954705583
# itération: 991 reward: -212.8330539078734
# itération: 992 reward: -268.04074018412905
# itération: 993 reward: -243.5956730230085
# itération: 994 reward: -236.49598740723644
# itération: 995 reward: -191.53608301651695
# itération: 996 reward: -229.05796337246426
# itération: 997 reward: -166.23228701838605
# itération: 998 reward: -200.60236653673692
# itération: 999 reward: -217.19205128382362
